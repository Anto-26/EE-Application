# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/jamesantoarnoldj/Desktop/Projects/EE App/data/raw/ee_data.csv")
df.shape
# Out:
# (26993, 14)

# %%
df.columns
# Out:
# Index(['Title', 'Place', 'Job_type', 'Department', 'Date', 'Overall_rating',
#        'work_life_balance', 'skill_development', 'salary_and_benefits',
#        'job_security', 'career_growth', 'work_satisfaction', 'Likes',
#        'Dislikes'],
#       dtype='object')

# %%
df.head()
# Out:
#                       Title                           Place   Job_type  \
# 0         Senior Consultant                            Pune  Full Time
# 1  Senior Software Engineer            Kolkata, West Bengal  Full Time
# 2         Senior Consultant  Bengaluru/Bangalore, Karnataka  Full Time
# 3         Senior Consultant               Pune, Maharashtra  Full Time
# 4                 Team Lead            Noida, Uttar Pradesh  Full Time
#
#                               Department        Date  Overall_rating  \
# 0           General Insurance Department  8 Sep 2023             4.0
# 1        Software Development Department  7 Sep 2023             3.0
# 2        Software Development Department  6 Sep 2023             4.0
# 3          Banking Operations Department  6 Sep 2023             1.0
# 4  IT Infrastructure Services Department  5 Sep 2023             4.0
#
#    work_life_balance  skill_development  salary_and_benefits  job_security  \
# 0                4.0                3.0                  3.0           4.0
# 1                4.0                4.0                  3.0           4.0
# 2                4.0                5.0                  3.0           3.0
# 3                2.0                4.0                  1.0           4.0
# 4                5.0                4.0                  4.0           4.0
#
#    career_growth  work_satisfaction  \
# 0            4.0                4.0
# 1            4.0                3.0
# 2            4.0                3.0
# 3            1.0                1.0
# 4            4.0                3.0
#
#                                                Likes  \
# 0  Deserved candidates are promoted promptly.\nUn...
# 1  You got lot of learning platform and monthly l...
# 2  Based on which Business Unit you are you will ...
# 3  Some client projects are good as they use the ...
# 4  I have worked in IBM (4 years) ,TCS (1 year) ,...
#
#                                             Dislikes
# 0  With designation promotions good salary increm...
# 1  You will get fully not tech project.\nThere is...
# 2  Some top level management people bring bad nam...
# 3  Culture, micro management, unprofessional beha...
# 4  Medical insurance amount is quite low compare ...

# %%
df[df["Job_type"].isnull()]
# Out:
#                                        Title  \
# 2189   Associate Consultant , Pega Developer
# 2249                       Software Engineer
# 2289                              Consultant
# 2379          Senior Professional I Engineer
# 2389                          Professional 1
# ...                                      ...
# 26988                        Senior Director
# 26989                      Senior Consultant
# 26990                        System Engineer
# 26991                          Hr Generalist
# 26992                         Resume  Writer
#
#                                    Place Job_type  \
# 2189   Hyderabad/Secunderabad, Telangana      NaN
# 2249                 Bhubaneswar, Odisha      NaN
# 2289                                Pune      NaN
# 2379           Gurgaon/Gurugram, Haryana      NaN
# 2389                 Bangalore/Bengaluru      NaN
# ...                                  ...      ...
# 26988                                NaN      NaN
# 26989                                NaN      NaN
# 26990                                NaN      NaN
# 26991                            Kolkata      NaN
# 26992                          Hyderabad      NaN
#
#                             Department        Date  Overall_rating  \
# 2189                Telecom Department  4 May 2023             3.0
# 2249   Software Development Department  5 Oct 2022             1.0
# 2289   Software Development Department  8 Apr 2023             5.0
# 2379   Software Development Department  0 May 2023             5.0
# 2389            Engineering Department  2 Sep 2023             4.0
# ...                                ...         ...             ...
# 26988           IT Security Department  5 Sep 2017             NaN
# 26989       Technology / IT Department  3 Sep 2017             NaN
# 26990            IT Network Department  7 Sep 2017             NaN
# 26991         HR Operations Department  6 Sep 2017             NaN
# 26992                              NaN  4 Mar 2018             NaN
#
#        work_life_balance  skill_development  salary_and_benefits  \
# 2189                 3.0                1.0                  2.0
# 2249                 1.0                4.0                  1.0
# 2289                 5.0                5.0                  5.0
# 2379                 5.0                3.0                  3.0
# 2389                 4.0                3.0                  4.0
# ...                  ...                ...                  ...
# 26988                1.0                1.0                  1.0
# 26989                5.0                1.0                  1.0
# 26990                3.0                3.0                  2.0
# 26991                4.0                3.0                  3.0
# 26992                NaN                NaN                  NaN
#
#        job_security  career_growth  work_satisfaction  \
# 2189            2.0            3.0                2.0
# 2249            4.0            1.0                1.0
# 2289            5.0            5.0                5.0
# 2379            5.0            5.0                2.0
# 2389            5.0            5.0                3.0
# ...             ...            ...                ...
# 26988           1.0            1.0                1.0
# 26989           4.0            2.0                1.0
# 26990           3.0            1.0                1.0
# 26991           4.0            4.0                2.0
# 26992           NaN            NaN                NaN
#
#                                                    Likes  \
# 2189   Company Culture and team management.\nFlexible...
# 2249   In Capgemini they will focus on your learning ...
# 2289   Excellent Company. No need to think about to j...
# 2379   Appresal \nDo not provide Festival / Occasion ...
# 2389                       Job security and work culture
# ...                                                  ...
# 26988  no stretched pressures on margins, which makes...
# 26989  capgemini quality resource hiring is missing.H...
# 26990          Very good employee engagement activities.
# 26991  The company is open to innovation and readily ...
# 26992                                                NaN
#
#                                                 Dislikes
# 2189   Not much when it comes to budget. More claps l...
# 2249   salary, benefits, appraisal is very very bad. ...
# 2289   Some projects doesn't have ODC in Hyderabad lo...
# 2379                                                 NaN
# 2389                 Opportunities to develop new skills
# ...                                                  ...
# 26988                                  very bureaucratic
# 26989                                               good
# 26990                  Career growth opportunity is less
# 26991                                                 No
# 26992                                                NaN
#
# [15437 rows x 14 columns]

# %%
df["Job_type"].value_counts()
# Out:
# Job_type
# Full Time      11340
# Contractual      131
# Intern            51
# Part Time         33
# Freelancer         1
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26993 entries, 0 to 26992
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Title                25912 non-null  object
#  1   Place                24597 non-null  object
#  2   Job_type             11556 non-null  object
#  3   Department           22083 non-null  object
#  4   Date                 25915 non-null  object
#  5   Overall_rating       25898 non-null  float64
#  6   work_life_balance    26977 non-null  float64
#  7   skill_development    26976 non-null  float64
#  8   salary_and_benefits  26947 non-null  float64
#  9   job_security         26943 non-null  float64
#  10  career_growth        26931 non-null  float64
#  11  work_satisfaction    26909 non-null  float64
#  12  Likes                23864 non-null  object
#  13  Dislikes             22966 non-null  object
# dtypes: float64(7), object(7)
# memory usage: 2.9+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
# %matplotlib inline

# %%
missing = pd.DataFrame({
    'missing_count': df.isnull().sum(),
    'missing_pct': (df.isnull().sum() / len(df) * 100).round(2)
}).sort_values('missing_count', ascending=False)

missing[missing['missing_count'] > 0]
# Out:
#                      missing_count  missing_pct
# Job_type                     15437        57.19
# Department                    4910        18.19
# Dislikes                      4027        14.92
# Likes                         3129        11.59
# Place                         2396         8.88
# Overall_rating                1095         4.06
# Title                         1081         4.00
# Date                          1078         3.99
# work_satisfaction               84         0.31
# career_growth                   62         0.23
# job_security                    50         0.19
# salary_and_benefits             46         0.17
# skill_development               17         0.06
# work_life_balance               16         0.06

# %%
df.describe().T

# %%
rating_cols = [
    'Overall_rating', 'work_life_balance', 'skill_development',
    'salary_and_benefits', 'job_security', 'career_growth', 'work_satisfaction'
]

fig, axes = plt.subplots(2, 4, figsize=(18, 9))
axes = axes.flatten()

for i, col in enumerate(rating_cols):
    counts = df[col].dropna().value_counts().sort_index()
    axes[i].bar(counts.index, counts.values, color='steelblue', edgecolor='white', width=0.6)
    axes[i].set_title(col.replace('_', ' ').title())
    axes[i].set_xlabel('Rating')
    axes[i].set_ylabel('Count')

axes[-1].set_visible(False)
plt.suptitle('Rating Distributions', fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()

# %%
rating_cols = [
    'Overall_rating', 'work_life_balance', 'skill_development',
    'salary_and_benefits', 'job_security', 'career_growth', 'work_satisfaction'
]

corr = df[rating_cols].corr()
plt.figure(figsize=(9, 7))
sns.heatmap(corr, annot=True, fmt='.2f', cmap='coolwarm', vmin=-1, vmax=1, square=True)
plt.title('Correlation Matrix – Rating Columns')
plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

top_dept = df['Department'].value_counts().head(10)
top_dept.plot(kind='barh', ax=axes[0], color='steelblue')
axes[0].set_title('Top 10 Departments')
axes[0].invert_yaxis()
axes[0].set_xlabel('Count')

top_title = df['Title'].value_counts().head(10)
top_title.plot(kind='barh', ax=axes[1], color='coral')
axes[1].set_title('Top 10 Job Titles')
axes[1].invert_yaxis()
axes[1].set_xlabel('Count')

top_place = df['Place'].value_counts().head(10)
top_place.plot(kind='barh', ax=axes[2], color='mediumseagreen')
axes[2].set_title('Top 10 Locations')
axes[2].invert_yaxis()
axes[2].set_xlabel('Count')

plt.tight_layout()
plt.show()

# %%
rating_cols = [
    'Overall_rating', 'work_life_balance', 'skill_development',
    'salary_and_benefits', 'job_security', 'career_growth', 'work_satisfaction'
]

avg_by_jobtype = df.groupby('Job_type')[rating_cols].mean()
avg_by_jobtype.plot(kind='bar', figsize=(12, 6), colormap='tab10', edgecolor='white')
plt.title('Average Ratings by Job Type')
plt.xlabel('Job Type')
plt.ylabel('Average Rating')
plt.xticks(rotation=0)
plt.legend(bbox_to_anchor=(1.01, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
import re

df_clean = df.copy()

# ── 1. Remove exact duplicate rows ────────────────────────────────────────────
before = len(df_clean)
df_clean.drop_duplicates(inplace=True)
print(f"Duplicates removed : {before - len(df_clean)}")
# Out:
# Duplicates removed : 546

# %%
# ── 2. Parse Date column ──────────────────────────────────────────────────────
# Some entries have a day of "0" (e.g. "0 May 2023") which are invalid.
# Replace day=0 with day=1 so pandas can parse them, then flag them.
def fix_date(val):
    if pd.isna(val):
        return pd.NaT
    val = str(val).strip()
    # Replace a leading "0 " day with "1 " so strptime can handle it
    val = re.sub(r'^0 ', '1 ', val)
    try:
        return pd.to_datetime(val, format="%d %b %Y")
    except Exception:
        return pd.NaT

df_clean["Date"] = df_clean["Date"].apply(fix_date)

unparseable = df_clean["Date"].isna().sum()
print(f"Unparseable dates (set to NaT) : {unparseable}")
print(f"Date range : {df_clean['Date'].min().date()} → {df_clean['Date'].max().date()}")
# Out:
# Unparseable dates (set to NaT) : 532
# Date range : 2017-08-01 → 2023-09-09

# %%
# ── 3. Standardise Department ─────────────────────────────────────────────────
# Strip trailing " Department" (case-insensitive) and whitespace
df_clean["Department"] = (
    df_clean["Department"]
    .str.strip()
    .str.replace(r"\s*department\s*$", "", case=False, regex=True)
    .str.strip()
    .fillna("Unknown")
)

print("Sample departments after cleaning:")
print(df_clean["Department"].value_counts().head(10))
# Out:
# Sample departments after cleaning:
# Department
# Software Development                 8936
# Unknown                              4364
# Quality Assurance and Testing        1942
# Accounting & Taxation                1287
# IT Consulting                        1017
# Finance                               762
# IT Network                            713
# Business Intelligence & Analytics     661
# IT Infrastructure Services            625
# Technology / IT                       618
# Name: count, dtype: int64

# %%
# ── 4. Clean Place  ───────────────────────────────────────────────────────────
# Many entries are "City, State" — extract just the city part.
# Also normalise common dual-name cities (e.g. "Bengaluru/Bangalore").
def extract_city(val):
    if pd.isna(val):
        return "Unknown"
    city = str(val).split(",")[0].strip()      # take part before first comma
    city = city.split("/")[0].strip()          # take part before first slash
    return city if city else "Unknown"

df_clean["Place"] = df_clean["Place"].apply(extract_city)

print("Top 10 cities after cleaning:")
print(df_clean["Place"].value_counts().head(10))
# Out:
# Top 10 cities after cleaning:
# Place
# Pune           3473
# Bengaluru      3422
# Bangalore      3184
# Hyderabad      2731
# Mumbai         2372
# Unknown        1850
# Chennai        1633
# Navi Mumbai    1480
# Kolkata        1201
# Noida          1198
# Name: count, dtype: int64

# %%
# ── 5. Fill categorical nulls ─────────────────────────────────────────────────
df_clean["Job_type"] = df_clean["Job_type"].fillna("Unknown")
df_clean["Title"]    = df_clean["Title"].str.strip().fillna("Unknown")

# Text feedback columns → empty string (preserves rows for the chatbot context)
df_clean["Likes"]    = df_clean["Likes"].fillna("")
df_clean["Dislikes"] = df_clean["Dislikes"].fillna("")

print("Job_type distribution:")
print(df_clean["Job_type"].value_counts())
# Out:
# Job_type distribution:
# Job_type
# Unknown        14891
# Full Time      11340
# Contractual      131
# Intern            51
# Part Time         33
# Freelancer         1
# Name: count, dtype: int64

# %%
# ── 6. Fill numeric rating nulls with column median ───────────────────────────
rating_cols = [
    "Overall_rating", "work_life_balance", "skill_development",
    "salary_and_benefits", "job_security", "career_growth", "work_satisfaction"
]

for col in rating_cols:
    median_val = df_clean[col].median()
    df_clean[col] = df_clean[col].fillna(median_val)

print("Missing values after fill:")
print(df_clean[rating_cols].isnull().sum())
# Out:
# Missing values after fill:
# Overall_rating         0
# work_life_balance      0
# skill_development      0
# salary_and_benefits    0
# job_security           0
# career_growth          0
# work_satisfaction      0
# dtype: int64

# %%
# ── 7. Final summary ──────────────────────────────────────────────────────────
print(f"Shape  : {df_clean.shape}  (was {df.shape})")
print(f"\nRemaining nulls:")
print(df_clean.isnull().sum()[df_clean.isnull().sum() > 0])
print("\nDtypes:")
print(df_clean.dtypes)
# Out:
# Shape  : (26447, 14)  (was (26993, 14))
#
# Remaining nulls:
# Date    532
# dtype: int64
#
# Dtypes:
# Title                          object
# Place                          object
# Job_type                       object
# Department                     object
# Date                   datetime64[ns]
# Overall_rating                float64
# work_life_balance             float64
# skill_development             float64
# salary_and_benefits           float64
# job_security                  float64
# career_growth                 float64
# work_satisfaction             float64
# Likes                          object
# Dislikes                       object
# dtype: object

# %%
df_clean
# Out:
#                           Title      Place   Job_type  \
# 0             Senior Consultant       Pune  Full Time
# 1      Senior Software Engineer    Kolkata  Full Time
# 2             Senior Consultant  Bengaluru  Full Time
# 3             Senior Consultant       Pune  Full Time
# 4                     Team Lead      Noida  Full Time
# ...                         ...        ...        ...
# 26988           Senior Director    Unknown    Unknown
# 26989         Senior Consultant    Unknown    Unknown
# 26990           System Engineer    Unknown    Unknown
# 26991             Hr Generalist    Kolkata    Unknown
# 26992            Resume  Writer  Hyderabad    Unknown
#
#                        Department       Date  Overall_rating  \
# 0               General Insurance 2023-09-08             4.0
# 1            Software Development 2023-09-07             3.0
# 2            Software Development 2023-09-06             4.0
# 3              Banking Operations 2023-09-06             1.0
# 4      IT Infrastructure Services 2023-09-05             4.0
# ...                           ...        ...             ...
# 26988                 IT Security 2017-09-05             4.0
# 26989             Technology / IT 2017-09-03             4.0
# 26990                  IT Network 2017-09-07             4.0
# 26991               HR Operations 2017-09-06             4.0
# 26992                     Unknown 2018-03-04             4.0
#
#        work_life_balance  skill_development  salary_and_benefits  \
# 0                    4.0                3.0                  3.0
# 1                    4.0                4.0                  3.0
# 2                    4.0                5.0                  3.0
# 3                    2.0                4.0                  1.0
# 4                    5.0                4.0                  4.0
# ...                  ...                ...                  ...
# 26988                1.0                1.0                  1.0
# 26989                5.0                1.0                  1.0
# 26990                3.0                3.0                  2.0
# 26991                4.0                3.0                  3.0
# 26992                4.0                4.0                  3.0
#
#        job_security  career_growth  work_satisfaction  \
# 0               4.0            4.0                4.0
# 1               4.0            4.0                3.0
# 2               3.0            4.0                3.0
# 3               4.0            1.0                1.0
# 4               4.0            4.0                3.0
# ...             ...            ...                ...
# 26988           1.0            1.0                1.0
# 26989           4.0            2.0                1.0
# 26990           3.0            1.0                1.0
# 26991           4.0            4.0                2.0
# 26992           4.0            4.0                3.0
#
#                                                    Likes  \
# 0      Deserved candidates are promoted promptly.\nUn...
# 1      You got lot of learning platform and monthly l...
# 2      Based on which Business Unit you are you will ...
# 3      Some client projects are good as they use the ...
# 4      I have worked in IBM (4 years) ,TCS (1 year) ,...
# ...                                                  ...
# 26988  no stretched pressures on margins, which makes...
# 26989  capgemini quality resource hiring is missing.H...
# 26990          Very good employee engagement activities.
# 26991  The company is open to innovation and readily ...
# 26992
#
#                                                 Dislikes
# 0      With designation promotions good salary increm...
# 1      You will get fully not tech project.\nThere is...
# 2      Some top level management people bring bad nam...
# 3      Culture, micro management, unprofessional beha...
# 4      Medical insurance amount is quite low compare ...
# ...                                                  ...
# 26988                                  very bureaucratic
# 26989                                               good
# 26990                  Career growth opportunity is less
# 26991                                                 No
# 26992
#
# [26447 rows x 14 columns]
